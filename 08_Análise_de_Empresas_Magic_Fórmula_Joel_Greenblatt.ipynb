# %% [markdown]
# <a href="https://colab.research.google.com/github/thefarofa/Invest/blob/main/08_An%C3%A1lise_de_Empresas_Magic_F%C3%B3rmula_Joel_Greenblatt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando Bibliotecas

# %%
import numpy as np
import pandas as pd
import string
import warnings
warnings.filterwarnings('ignore')

import requests

# %% [markdown]
# # Obtendo e tratando os dados

# %%
url = 'http://www.fundamentus.com.br/resultado.php'

# %%
header = {
  "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"
 }

r = requests.get(url, headers=header)

# %%
df = pd.read_html(r.text,  decimal=',', thousands='.')[0]

# %%
df
# Out:
#       Papel  Cotação      P/L   P/VP    PSR Div.Yield  P/Ativo  P/Cap.Giro  \
# 0     IVTT3     0.00     0.00   0.00  0.000     0,00%     0.00        0.00
# 1     CSTB3   150.00     0.00   0.00  0.000     0,00%     0.00        0.00
# 2     CSTB4   147.69     0.00   0.00  0.000     0,00%     0.00        0.00
# 3     CFLU4  1000.00     0.00   0.00  0.000     0,00%     0.00        0.00
# 4     PORP4     2.40     0.00   0.00  0.000     0,00%     0.00        0.00
# ..      ...      ...      ...    ...    ...       ...      ...         ...
# 981   PRBC4    14.54   502.29  40.26  0.000     0,00%     0.00        0.00
# 982   UBBR4     7.49   610.27   1.99  0.000     0,00%     0.00        0.00
# 983  UBBR11    14.75  1201.81   3.91  0.000     0,00%     0.00        0.00
# 984   UBBR3    18.00  1466.61   4.77  0.000     0,00%     0.00        0.00
# 985   SQIA3    27.19  2726.50   3.74  3.642     0,20%     1.49       26.87
#
# ...

# %%
for coluna in ['Div.Yield', 'Mrg Ebit', 'Mrg. Líq.', 'ROIC', 'ROE', 'Cresc. Rec.5a']:
  df[coluna] = df[coluna].str.replace('.', '')
  df[coluna] = df[coluna].str.replace(',', '.')
  df[coluna] = df[coluna].str.rstrip('%').astype('float') / 100

# %% [markdown]
# # Analisando os dados

# %%
df = df[df['Liq.2meses'] > 1000000]

# %%
ranking = pd.DataFrame()
ranking['pos'] = range(1,151)
ranking['EV/EBIT'] = df[ df['EV/EBIT'] > 0 ].sort_values(by=['EV/EBIT'])['Papel'][:150].values
ranking['ROIC'] = df.sort_values(by=['ROIC'], ascending=False)['Papel'][:150].values

# %%
ranking
# Out:
#      pos EV/EBIT   ROIC
# 0      1   PSSA3  PSSA3
# 1      2   NINJ3  KEPL3
# 2      3   GOAU4  UNIP6
# 3      4   WIZC3  ODPV3
# 4      5   PETR4  LEVE3
# ..   ...     ...    ...
# 145  146   MGLU3  EMBR3
# 146  147   VIVA3  CEAB3
# 147  148  IGTI11  CIEL3
# 148  149   GRND3  COGN3
# 149  150   TFCO4  AESB3
#
# [150 rows x 3 columns]

# %%
a = ranking.pivot_table(columns='EV/EBIT', values='pos')

# %%
b = ranking.pivot_table(columns='ROIC', values='pos')

# %%
t = pd.concat([a,b])
t
# Out:
#      ABEV3  AERI3  AGRO3  ALSO3  ALUP11  AMBP3  AMER3  ANIM3  ARML3  ARZZ3  \
# pos    122     37    120  134.0      73     62  109.0     91    142    143
# pos     47     60     95    NaN     103     73    NaN    134     62     83
#
#      ...  AESB3  ELMD3  FLRY3  MDIA3  PNVL3  RADL3  RAIL3  RENT3  VBBR3  WEGE3
# pos  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# pos  ...  150.0  117.0  127.0  115.0  131.0   57.0  124.0  107.0  136.0    6.0
#
# [2 rows x 160 columns]

# %%
rank = t.dropna(axis=1).sum()
rank
# Out:
# ABEV3     169
# AERI3      97
# AGRO3     215
# ALUP11    176
# AMBP3     135
#          ...
# VLID3      31
# VULC3     128
# VVEO3     232
# WIZC3      20
# YDUQ3     238
# Length: 140, dtype: int64

# %%
rank.sort_values()[:30]
# Out:
# PSSA3      2
# PETR3     15
# PETR4     15
# WIZC3     20
# PLPL3     21
# KEPL3     24
# UNIP6     27
# VLID3     31
# FESA4     34
# GOAU4     35
# GGBR3     38
# VALE3     38
# GGBR4     38
# CMIN3     44
# TASA4     45
# LREN3     48
# PRNR3     49
# LEVE3     53
# CMIG4     55
# AURA33    60
# CSUD3     60
# BEEF3     62
# RAPT4     66
# RECV3     67
# SAPR3     70
# TGMA3     71
# SAPR4     72
# CPFE3     73
# SAPR11    74
# CURY3     74
# dtype: int64
